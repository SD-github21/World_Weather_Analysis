# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinatins.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citypy module to determine city based on latitude and longitude. 
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 715

# %%
# Import the requests library. 
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# loop through all the cities in the list. 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

# Run an API request for each of the cities. 
    try: 
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wdesc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_wdesc})
#If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | carnarvon
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | iqaluit
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | saint-joseph
# Processing Record 10 of Set 1 | petukhovo
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | mutoko
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | chicama
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | souillac
# Processing Record 18 of Set 1 | blackwater
# Processing Record 19 of Set 1 | esperance
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | gat
# Processing Record 25 of Set 1 | guerrero negro
# Processing Record 26 of Set 1 | kitami
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | sorland
# Processing Record 29 of Set 1 | luderitz
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | thakurgaon
# Processing Record 32 of Set 1 | skjervoy
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | cheuskiny
# City not found. Skipping...
# Processing Record 35 of Set 1 | rocha
# Processing Record 36 of Set 1 | cidreira
# Processing Record 37 of Set 1 | severo-kurilsk
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | soe
# Processing Record 40 of Set 1 | ancud
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | erdenet
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | shakiso
# Processing Record 46 of Set 1 | yar-sale
# Processing Record 47 of Set 1 | mahadday weyne
# City not found. Skipping...
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | nanakuli
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | sibolga
# Processing Record 3 of Set 2 | san quintin
# Processing Record 4 of Set 2 | havelock
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | imeni poliny osipenko
# Processing Record 8 of Set 2 | abilene
# Processing Record 9 of Set 2 | umm lajj
# Processing Record 10 of Set 2 | vao
# Processing Record 11 of Set 2 | chuy
# Processing Record 12 of Set 2 | comodoro rivadavia
# Processing Record 13 of Set 2 | lavrentiya
# Processing Record 14 of Set 2 | kavieng
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | college
# Processing Record 19 of Set 2 | kaoma
# Processing Record 20 of Set 2 | huntsville
# Processing Record 21 of Set 2 | tsienyane
# City not found. Skipping...
# Processing Record 22 of Set 2 | vostok
# Processing Record 23 of Set 2 | manica
# Processing Record 24 of Set 2 | roxana
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | darhan
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | provideniya
# Processing Record 29 of Set 2 | aklavik
# Processing Record 30 of Set 2 | smithers
# Processing Record 31 of Set 2 | gizo
# Processing Record 32 of Set 2 | banjar
# Processing Record 33 of Set 2 | andevoranto
# City not found. Skipping...
# Processing Record 34 of Set 2 | asau
# Processing Record 35 of Set 2 | namibe
# Processing Record 36 of Set 2 | tuktoyaktuk
# Processing Record 37 of Set 2 | mukhen
# Processing Record 38 of Set 2 | vestmannaeyjar
# Processing Record 39 of Set 2 | katsuura
# Processing Record 40 of Set 2 | torbay
# Processing Record 41 of Set 2 | erenhot
# Processing Record 42 of Set 2 | saldanha
# Processing Record 43 of Set 2 | goderich
# Processing Record 44 of Set 2 | bathsheba
# Processing Record 45 of Set 2 | haines junction
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | santa rosa
# Processing Record 48 of Set 2 | agirish
# Processing Record 49 of Set 2 | tromso
# Processing Record 50 of Set 2 | shirgaon
# Processing Record 1 of Set 3 | harpanahalli
# Processing Record 2 of Set 3 | hrubieszow
# Processing Record 3 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 3 | dingle
# Processing Record 5 of Set 3 | kuryk
# Processing Record 6 of Set 3 | batagay
# Processing Record 7 of Set 3 | castro
# Processing Record 8 of Set 3 | ust-ilimsk
# Processing Record 9 of Set 3 | metro
# Processing Record 10 of Set 3 | vidim
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | hasaki
# Processing Record 13 of Set 3 | totma
# Processing Record 14 of Set 3 | cockburn town
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | fortuna
# Processing Record 17 of Set 3 | mar del plata
# Processing Record 18 of Set 3 | kayerkan
# Processing Record 19 of Set 3 | obo
# Processing Record 20 of Set 3 | hunterville
# Processing Record 21 of Set 3 | labuan
# Processing Record 22 of Set 3 | tautira
# Processing Record 23 of Set 3 | gisborne
# Processing Record 24 of Set 3 | atuona
# Processing Record 25 of Set 3 | cayenne
# Processing Record 26 of Set 3 | pevek
# Processing Record 27 of Set 3 | berbera
# Processing Record 28 of Set 3 | faanui
# Processing Record 29 of Set 3 | buala
# Processing Record 30 of Set 3 | rio grande
# Processing Record 31 of Set 3 | lagoa
# Processing Record 32 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 3 | batsfjord
# Processing Record 34 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | kipini
# Processing Record 37 of Set 3 | ribeira grande
# Processing Record 38 of Set 3 | sao joao da barra
# Processing Record 39 of Set 3 | aljezur
# Processing Record 40 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 41 of Set 3 | georgetown
# Processing Record 42 of Set 3 | pinehurst
# Processing Record 43 of Set 3 | kokkola
# Processing Record 44 of Set 3 | broome
# Processing Record 45 of Set 3 | ko samui
# Processing Record 46 of Set 3 | keetmanshoop
# Processing Record 47 of Set 3 | grindavik
# Processing Record 48 of Set 3 | tura
# Processing Record 49 of Set 3 | nanortalik
# Processing Record 50 of Set 3 | sept-iles
# Processing Record 1 of Set 4 | kampong cham
# Processing Record 2 of Set 4 | burica
# City not found. Skipping...
# Processing Record 3 of Set 4 | labuhan
# Processing Record 4 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 4 | puerto ayora
# Processing Record 6 of Set 4 | narsaq
# Processing Record 7 of Set 4 | husavik
# Processing Record 8 of Set 4 | samarinda
# Processing Record 9 of Set 4 | kaitangata
# Processing Record 10 of Set 4 | yellowknife
# Processing Record 11 of Set 4 | la victoria
# Processing Record 12 of Set 4 | boyuibe
# Processing Record 13 of Set 4 | cabo san lucas
# Processing Record 14 of Set 4 | san policarpo
# Processing Record 15 of Set 4 | eidsvag
# Processing Record 16 of Set 4 | dongsheng
# Processing Record 17 of Set 4 | mumford
# Processing Record 18 of Set 4 | qaanaaq
# Processing Record 19 of Set 4 | puerto escondido
# Processing Record 20 of Set 4 | xining
# Processing Record 21 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 4 | tessalit
# Processing Record 23 of Set 4 | mount gambier
# Processing Record 24 of Set 4 | mahebourg
# Processing Record 25 of Set 4 | taburao
# City not found. Skipping...
# Processing Record 26 of Set 4 | yemelyanovo
# Processing Record 27 of Set 4 | sangar
# Processing Record 28 of Set 4 | avarua
# Processing Record 29 of Set 4 | barkaker
# Processing Record 30 of Set 4 | hamilton
# Processing Record 31 of Set 4 | bambous virieux
# Processing Record 32 of Set 4 | harper
# Processing Record 33 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | jorpeland
# Processing Record 36 of Set 4 | nongstoin
# Processing Record 37 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 4 | nuuk
# Processing Record 39 of Set 4 | buchanan
# Processing Record 40 of Set 4 | nefteyugansk
# Processing Record 41 of Set 4 | tahe
# Processing Record 42 of Set 4 | gayeri
# Processing Record 43 of Set 4 | ust-kuyga
# Processing Record 44 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 4 | dukhovnitskoye
# Processing Record 46 of Set 4 | flin flon
# Processing Record 47 of Set 4 | atar
# Processing Record 48 of Set 4 | bethel
# Processing Record 49 of Set 4 | bumba
# Processing Record 50 of Set 4 | saint george
# Processing Record 1 of Set 5 | mount isa
# Processing Record 2 of Set 5 | hobart
# Processing Record 3 of Set 5 | sarkand
# Processing Record 4 of Set 5 | chaman
# Processing Record 5 of Set 5 | dunedin
# Processing Record 6 of Set 5 | verkhoyansk
# Processing Record 7 of Set 5 | vila franca do campo
# Processing Record 8 of Set 5 | gogrial
# Processing Record 9 of Set 5 | parga
# Processing Record 10 of Set 5 | phitsanulok
# Processing Record 11 of Set 5 | ridgecrest
# Processing Record 12 of Set 5 | salalah
# Processing Record 13 of Set 5 | necochea
# Processing Record 14 of Set 5 | gondar
# Processing Record 15 of Set 5 | osypenko
# Processing Record 16 of Set 5 | pizarro
# Processing Record 17 of Set 5 | ladnun
# Processing Record 18 of Set 5 | oktyabrskoye
# Processing Record 19 of Set 5 | forio
# Processing Record 20 of Set 5 | fayaoue
# Processing Record 21 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 5 | gamba
# Processing Record 23 of Set 5 | champerico
# Processing Record 24 of Set 5 | frontera
# Processing Record 25 of Set 5 | makakilo city
# Processing Record 26 of Set 5 | dezhou
# Processing Record 27 of Set 5 | xichang
# Processing Record 28 of Set 5 | bosobolo
# Processing Record 29 of Set 5 | leshukonskoye
# Processing Record 30 of Set 5 | ceres
# Processing Record 31 of Set 5 | kautokeino
# Processing Record 32 of Set 5 | kahului
# Processing Record 33 of Set 5 | nikolskoye
# Processing Record 34 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 35 of Set 5 | jiaojiang
# Processing Record 36 of Set 5 | ambilobe
# Processing Record 37 of Set 5 | constitucion
# Processing Record 38 of Set 5 | bowen
# Processing Record 39 of Set 5 | dalby
# Processing Record 40 of Set 5 | vyazma
# Processing Record 41 of Set 5 | mikhaylovka
# Processing Record 42 of Set 5 | chapais
# Processing Record 43 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 5 | namatanai
# Processing Record 45 of Set 5 | molepolole
# Processing Record 46 of Set 5 | salinas
# Processing Record 47 of Set 5 | saint-philippe
# Processing Record 48 of Set 5 | caravelas
# Processing Record 49 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 5 | kutum
# Processing Record 1 of Set 6 | kapuskasing
# Processing Record 2 of Set 6 | araouane
# Processing Record 3 of Set 6 | norman wells
# Processing Record 4 of Set 6 | anito
# Processing Record 5 of Set 6 | port hardy
# Processing Record 6 of Set 6 | klaksvik
# Processing Record 7 of Set 6 | carutapera
# Processing Record 8 of Set 6 | gafanha da encarnacao
# Processing Record 9 of Set 6 | morros
# Processing Record 10 of Set 6 | saskylakh
# Processing Record 11 of Set 6 | san patricio
# Processing Record 12 of Set 6 | oktyabrskiy
# Processing Record 13 of Set 6 | sechelt
# Processing Record 14 of Set 6 | linares
# Processing Record 15 of Set 6 | wajir
# Processing Record 16 of Set 6 | sobreira
# Processing Record 17 of Set 6 | deputatskiy
# Processing Record 18 of Set 6 | san luis
# Processing Record 19 of Set 6 | berlevag
# Processing Record 20 of Set 6 | blythe
# Processing Record 21 of Set 6 | muroto
# Processing Record 22 of Set 6 | verkhnevilyuysk
# Processing Record 23 of Set 6 | codrington
# Processing Record 24 of Set 6 | broken hill
# Processing Record 25 of Set 6 | marrakesh
# Processing Record 26 of Set 6 | puerto del rosario
# Processing Record 27 of Set 6 | conde
# Processing Record 28 of Set 6 | margate
# Processing Record 29 of Set 6 | ocampo
# Processing Record 30 of Set 6 | tuatapere
# Processing Record 31 of Set 6 | beloha
# Processing Record 32 of Set 6 | woudenberg
# Processing Record 33 of Set 6 | lasa
# Processing Record 34 of Set 6 | jumla
# Processing Record 35 of Set 6 | sitka
# Processing Record 36 of Set 6 | smoky lake
# Processing Record 37 of Set 6 | adzope
# Processing Record 38 of Set 6 | zlitan
# Processing Record 39 of Set 6 | ukiah
# Processing Record 40 of Set 6 | ruidoso
# Processing Record 41 of Set 6 | gushikawa
# Processing Record 42 of Set 6 | talnakh
# Processing Record 43 of Set 6 | waikuku
# Processing Record 44 of Set 6 | ponnampet
# Processing Record 45 of Set 6 | teahupoo
# Processing Record 46 of Set 6 | najran
# Processing Record 47 of Set 6 | qandala
# Processing Record 48 of Set 6 | mormugao
# Processing Record 49 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 6 | shevchenko
# Processing Record 1 of Set 7 | rundu
# Processing Record 2 of Set 7 | vilyuysk
# Processing Record 3 of Set 7 | kamenka
# Processing Record 4 of Set 7 | nelson bay
# Processing Record 5 of Set 7 | state college
# Processing Record 6 of Set 7 | talesh
# City not found. Skipping...
# Processing Record 7 of Set 7 | meulaboh
# Processing Record 8 of Set 7 | punta alta
# Processing Record 9 of Set 7 | sawtell
# Processing Record 10 of Set 7 | nueva gerona
# Processing Record 11 of Set 7 | cacador
# Processing Record 12 of Set 7 | kilindoni
# Processing Record 13 of Set 7 | bonthe
# Processing Record 14 of Set 7 | beidao
# Processing Record 15 of Set 7 | kalabo
# Processing Record 16 of Set 7 | kuytun
# Processing Record 17 of Set 7 | srandakan
# Processing Record 18 of Set 7 | turukhansk
# Processing Record 19 of Set 7 | gustavo diaz ordaz
# Processing Record 20 of Set 7 | kavaratti
# Processing Record 21 of Set 7 | oromocto
# Processing Record 22 of Set 7 | east london
# Processing Record 23 of Set 7 | pierre
# Processing Record 24 of Set 7 | jurmala
# Processing Record 25 of Set 7 | tottori
# Processing Record 26 of Set 7 | semnan
# Processing Record 27 of Set 7 | victoria
# Processing Record 28 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 29 of Set 7 | damara
# Processing Record 30 of Set 7 | foumbot
# Processing Record 31 of Set 7 | akdepe
# Processing Record 32 of Set 7 | mosquera
# Processing Record 33 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 7 | belaya gora
# Processing Record 35 of Set 7 | havre-saint-pierre
# Processing Record 36 of Set 7 | innisfail
# Processing Record 37 of Set 7 | thaba-tseka
# Processing Record 38 of Set 7 | ochakiv
# Processing Record 39 of Set 7 | kaeo
# Processing Record 40 of Set 7 | longyearbyen
# Processing Record 41 of Set 7 | isangel
# Processing Record 42 of Set 7 | takoradi
# Processing Record 43 of Set 7 | lompoc
# Processing Record 44 of Set 7 | nouadhibou
# Processing Record 45 of Set 7 | revelstoke
# Processing Record 46 of Set 7 | nador
# Processing Record 47 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 7 | kabala
# Processing Record 49 of Set 7 | richards bay
# Processing Record 50 of Set 7 | port blair
# Processing Record 1 of Set 8 | polunochnoye
# Processing Record 2 of Set 8 | mabua
# Processing Record 3 of Set 8 | muros
# Processing Record 4 of Set 8 | fare
# Processing Record 5 of Set 8 | kingston
# Processing Record 6 of Set 8 | maarianhamina
# Processing Record 7 of Set 8 | tskaltubo
# Processing Record 8 of Set 8 | fort morgan
# Processing Record 9 of Set 8 | frei paulo
# Processing Record 10 of Set 8 | ilulissat
# Processing Record 11 of Set 8 | nikel
# Processing Record 12 of Set 8 | muisne
# Processing Record 13 of Set 8 | ouadda
# Processing Record 14 of Set 8 | yulara
# Processing Record 15 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 16 of Set 8 | belmopan
# Processing Record 17 of Set 8 | chimbote
# Processing Record 18 of Set 8 | geraldton
# Processing Record 19 of Set 8 | mangai
# Processing Record 20 of Set 8 | madimba
# Processing Record 21 of Set 8 | fort madison
# Processing Record 22 of Set 8 | mizpe ramon
# City not found. Skipping...
# Processing Record 23 of Set 8 | san javier
# Processing Record 24 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 25 of Set 8 | tarko-sale
# Processing Record 26 of Set 8 | koshurnikovo
# Processing Record 27 of Set 8 | kargasok
# Processing Record 28 of Set 8 | neiafu
# Processing Record 29 of Set 8 | alexandria
# Processing Record 30 of Set 8 | beyneu
# Processing Record 31 of Set 8 | lagos
# Processing Record 32 of Set 8 | chunoyar
# Processing Record 33 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 8 | namtsy
# Processing Record 35 of Set 8 | ilan
# Processing Record 36 of Set 8 | bani walid
# Processing Record 37 of Set 8 | nyurba
# Processing Record 38 of Set 8 | tazovskiy
# Processing Record 39 of Set 8 | port lincoln
# Processing Record 40 of Set 8 | shahe
# Processing Record 41 of Set 8 | severodvinsk
# Processing Record 42 of Set 8 | vila do maio
# Processing Record 43 of Set 8 | sungairaya
# Processing Record 44 of Set 8 | gigmoto
# Processing Record 45 of Set 8 | jalu
# Processing Record 46 of Set 8 | eyl
# Processing Record 47 of Set 8 | palmer
# Processing Record 48 of Set 8 | bodden town
# Processing Record 49 of Set 8 | ostrovnoy
# Processing Record 50 of Set 8 | khorixas
# Processing Record 1 of Set 9 | moerai
# Processing Record 2 of Set 9 | nhulunbuy
# Processing Record 3 of Set 9 | poum
# Processing Record 4 of Set 9 | cabedelo
# Processing Record 5 of Set 9 | yatou
# Processing Record 6 of Set 9 | kaseda
# Processing Record 7 of Set 9 | tuy hoa
# Processing Record 8 of Set 9 | qasigiannguit
# Processing Record 9 of Set 9 | stepantsevo
# Processing Record 10 of Set 9 | almaznyy
# Processing Record 11 of Set 9 | pa sang
# Processing Record 12 of Set 9 | pedernales
# Processing Record 13 of Set 9 | bousso
# Processing Record 14 of Set 9 | bonito
# Processing Record 15 of Set 9 | naryan-mar
# Processing Record 16 of Set 9 | zhuhai
# Processing Record 17 of Set 9 | okoneshnikovo
# Processing Record 18 of Set 9 | ariquemes
# Processing Record 19 of Set 9 | chumikan
# Processing Record 20 of Set 9 | avenal
# Processing Record 21 of Set 9 | pacific grove
# Processing Record 22 of Set 9 | acapulco
# Processing Record 23 of Set 9 | kruisfontein
# Processing Record 24 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 9 | alice springs
# Processing Record 26 of Set 9 | latung
# Processing Record 27 of Set 9 | bambanglipuro
# Processing Record 28 of Set 9 | beira
# Processing Record 29 of Set 9 | boyolangu
# Processing Record 30 of Set 9 | cururupu
# Processing Record 31 of Set 9 | trinidad
# Processing Record 32 of Set 9 | ambon
# Processing Record 33 of Set 9 | awbari
# Processing Record 34 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 9 | tilichiki
# Processing Record 36 of Set 9 | honningsvag
# Processing Record 37 of Set 9 | clyde river
# Processing Record 38 of Set 9 | heinola
# Processing Record 39 of Set 9 | mae hong son
# Processing Record 40 of Set 9 | lujan
# Processing Record 41 of Set 9 | phetchaburi
# Processing Record 42 of Set 9 | vung tau
# Processing Record 43 of Set 9 | muravlenko
# Processing Record 44 of Set 9 | araci
# Processing Record 45 of Set 9 | karasburg
# Processing Record 46 of Set 9 | ewa beach
# Processing Record 47 of Set 9 | sao filipe
# Processing Record 48 of Set 9 | malakal
# Processing Record 49 of Set 9 | araceli
# Processing Record 50 of Set 9 | daru
# Processing Record 1 of Set 10 | praia
# Processing Record 2 of Set 10 | songjianghe
# Processing Record 3 of Set 10 | batemans bay
# Processing Record 4 of Set 10 | hofn
# Processing Record 5 of Set 10 | orlik
# Processing Record 6 of Set 10 | sal rei
# Processing Record 7 of Set 10 | natal
# Processing Record 8 of Set 10 | mwene-ditu
# Processing Record 9 of Set 10 | csaszar
# Processing Record 10 of Set 10 | mbandaka
# Processing Record 11 of Set 10 | shenjiamen
# Processing Record 12 of Set 10 | mugur-aksy
# Processing Record 13 of Set 10 | naugarzan
# City not found. Skipping...
# Processing Record 14 of Set 10 | rosarito
# Processing Record 15 of Set 10 | rudnyy
# Processing Record 16 of Set 10 | puerto princesa
# Processing Record 17 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 18 of Set 10 | belmonte
# Processing Record 19 of Set 10 | south sioux city
# Processing Record 20 of Set 10 | lorengau
# Processing Record 21 of Set 10 | marawi
# Processing Record 22 of Set 10 | hobyo
# Processing Record 23 of Set 10 | leh
# Processing Record 24 of Set 10 | mezen
# Processing Record 25 of Set 10 | pljevlja
# Processing Record 26 of Set 10 | mahibadhoo
# Processing Record 27 of Set 10 | cochabamba
# Processing Record 28 of Set 10 | opuwo
# Processing Record 29 of Set 10 | kudahuvadhoo
# Processing Record 30 of Set 10 | nabire
# Processing Record 31 of Set 10 | ormara
# Processing Record 32 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 10 | korla
# Processing Record 34 of Set 10 | santa isabel
# Processing Record 35 of Set 10 | lopez
# Processing Record 36 of Set 10 | danielskuil
# Processing Record 37 of Set 10 | apastovo
# Processing Record 38 of Set 10 | aksehir
# Processing Record 39 of Set 10 | storforshei
# Processing Record 40 of Set 10 | vila velha
# Processing Record 41 of Set 10 | sioux lookout
# Processing Record 42 of Set 10 | byron bay
# Processing Record 43 of Set 10 | libertador general san martin
# Processing Record 44 of Set 10 | torva
# Processing Record 45 of Set 10 | pisco
# Processing Record 46 of Set 10 | saint-pierre
# Processing Record 47 of Set 10 | estreito
# Processing Record 48 of Set 10 | buta
# Processing Record 49 of Set 10 | xingtai
# Processing Record 50 of Set 10 | bairiki
# Processing Record 1 of Set 11 | raudeberg
# Processing Record 2 of Set 11 | maniitsoq
# Processing Record 3 of Set 11 | yaritagua
# Processing Record 4 of Set 11 | homer
# Processing Record 5 of Set 11 | lahij
# Processing Record 6 of Set 11 | fort nelson
# Processing Record 7 of Set 11 | mlyniv
# Processing Record 8 of Set 11 | xacmaz
# Processing Record 9 of Set 11 | zuwarah
# Processing Record 10 of Set 11 | repatriacion
# Processing Record 11 of Set 11 | sardarpur
# Processing Record 12 of Set 11 | klerksdorp
# Processing Record 13 of Set 11 | kichmengskiy gorodok
# Processing Record 14 of Set 11 | beya
# Processing Record 15 of Set 11 | avera
# Processing Record 16 of Set 11 | la union
# Processing Record 17 of Set 11 | weilburg
# Processing Record 18 of Set 11 | kalanguy
# Processing Record 19 of Set 11 | lata
# Processing Record 20 of Set 11 | emerald
# Processing Record 21 of Set 11 | kirsanov
# Processing Record 22 of Set 11 | dondo
# Processing Record 23 of Set 11 | kirakira
# Processing Record 24 of Set 11 | sur
# Processing Record 25 of Set 11 | talara
# Processing Record 26 of Set 11 | troitskoye
# Processing Record 27 of Set 11 | krasnyy chikoy
# Processing Record 28 of Set 11 | tamala
# Processing Record 29 of Set 11 | portland
# Processing Record 30 of Set 11 | diamantino
# Processing Record 31 of Set 11 | thessalon
# Processing Record 32 of Set 11 | adrar
# Processing Record 33 of Set 11 | sibi
# Processing Record 34 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 11 | amga
# Processing Record 36 of Set 11 | hohhot
# Processing Record 37 of Set 11 | touros
# Processing Record 38 of Set 11 | shingu
# Processing Record 39 of Set 11 | maningrida
# Processing Record 40 of Set 11 | mao
# Processing Record 41 of Set 11 | jutai
# Processing Record 42 of Set 11 | onega
# Processing Record 43 of Set 11 | nakamura
# Processing Record 44 of Set 11 | agadir
# Processing Record 45 of Set 11 | coyah
# Processing Record 46 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 47 of Set 11 | mengcheng
# Processing Record 48 of Set 11 | hervey bay
# Processing Record 49 of Set 11 | magole
# Processing Record 50 of Set 11 | nicoya
# Processing Record 1 of Set 12 | port moresby
# Processing Record 2 of Set 12 | rio gallegos
# Processing Record 3 of Set 12 | jasper
# Processing Record 4 of Set 12 | athabasca
# Processing Record 5 of Set 12 | ismailia
# Processing Record 6 of Set 12 | grand gaube
# Processing Record 7 of Set 12 | xiongzhou
# Processing Record 8 of Set 12 | ankazoabo
# Processing Record 9 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 12 | zaraza
# Processing Record 11 of Set 12 | anchorage
# Processing Record 12 of Set 12 | bilma
# Processing Record 13 of Set 12 | joshimath
# Processing Record 14 of Set 12 | wanning
# Processing Record 15 of Set 12 | lokosovo
# Processing Record 16 of Set 12 | dasoguz
# Processing Record 17 of Set 12 | bubaque
# Processing Record 18 of Set 12 | mayumba
# Processing Record 19 of Set 12 | barcelos
# Processing Record 20 of Set 12 | majene
# Processing Record 21 of Set 12 | elat
# Processing Record 22 of Set 12 | leningradskiy
# Processing Record 23 of Set 12 | jijiga
# Processing Record 24 of Set 12 | nuristan
# Processing Record 25 of Set 12 | pangkalanbuun
# Processing Record 26 of Set 12 | vallenar
# Processing Record 27 of Set 12 | bhadrachalam
# Processing Record 28 of Set 12 | kofele
# Processing Record 29 of Set 12 | neftcala
# Processing Record 30 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 31 of Set 12 | alpatovo
# Processing Record 32 of Set 12 | udachnyy
# Processing Record 33 of Set 12 | naze
# Processing Record 34 of Set 12 | ust-ordynskiy
# Processing Record 35 of Set 12 | srednekolymsk
# Processing Record 36 of Set 12 | olavarria
# Processing Record 37 of Set 12 | ubon ratchathani
# Processing Record 38 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 12 | changji
# Processing Record 40 of Set 12 | hay river
# Processing Record 41 of Set 12 | bagdarin
# Processing Record 42 of Set 12 | maridi
# Processing Record 43 of Set 12 | gorontalo
# Processing Record 44 of Set 12 | sinnamary
# Processing Record 45 of Set 12 | hami
# Processing Record 46 of Set 12 | polazna
# Processing Record 47 of Set 12 | freeport
# Processing Record 48 of Set 12 | antofagasta
# Processing Record 49 of Set 12 | huarmey
# Processing Record 50 of Set 12 | bilasipara
# Processing Record 1 of Set 13 | komsomolskiy
# Processing Record 2 of Set 13 | umm kaddadah
# Processing Record 3 of Set 13 | los llanos de aridane
# Processing Record 4 of Set 13 | rincon
# Processing Record 5 of Set 13 | urumqi
# Processing Record 6 of Set 13 | buraydah
# Processing Record 7 of Set 13 | celestun
# Processing Record 8 of Set 13 | albury
# Processing Record 9 of Set 13 | karla
# Processing Record 10 of Set 13 | russell
# Processing Record 11 of Set 13 | watsonville
# Processing Record 12 of Set 13 | batagay-alyta
# Processing Record 13 of Set 13 | mufulira
# Processing Record 14 of Set 13 | itarema
# Processing Record 15 of Set 13 | santa isabel do rio negro
# Processing Record 16 of Set 13 | lahat
# Processing Record 17 of Set 13 | mayna
# Processing Record 18 of Set 13 | kumbo
# Processing Record 19 of Set 13 | jinchang
# Processing Record 20 of Set 13 | angoche
# Processing Record 21 of Set 13 | valdivia
# Processing Record 22 of Set 13 | omutinskoye
# City not found. Skipping...
# Processing Record 23 of Set 13 | pietarsaari
# Processing Record 24 of Set 13 | vardo
# Processing Record 25 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 13 | severnyy-kospashskiy
# Processing Record 27 of Set 13 | nizhnevartovsk
# Processing Record 28 of Set 13 | sakakah
# Processing Record 29 of Set 13 | olafsvik
# Processing Record 30 of Set 13 | catalao
# Processing Record 31 of Set 13 | okha
# Processing Record 32 of Set 13 | sabha
# Processing Record 33 of Set 13 | machado
# Processing Record 34 of Set 13 | whitefish
# Processing Record 35 of Set 13 | talas
# Processing Record 36 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 37 of Set 13 | mawlaik
# Processing Record 38 of Set 13 | san cristobal
# Processing Record 39 of Set 13 | sao bartolomeu de messines
# Processing Record 40 of Set 13 | encinitas
# Processing Record 41 of Set 13 | saqqez
# Processing Record 42 of Set 13 | sakaiminato
# Processing Record 43 of Set 13 | thinadhoo
# Processing Record 44 of Set 13 | owase
# Processing Record 45 of Set 13 | peleduy
# Processing Record 46 of Set 13 | chicaman
# Processing Record 47 of Set 13 | normandin
# Processing Record 48 of Set 13 | aksarka
# Processing Record 49 of Set 13 | itupiranga
# Processing Record 50 of Set 13 | sao felix do xingu
# Processing Record 1 of Set 14 | yunjinghong
# City not found. Skipping...
# Processing Record 2 of Set 14 | napierville
# Processing Record 3 of Set 14 | vadinsk
# Processing Record 4 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 14 | luena
# Processing Record 6 of Set 14 | rayon
# Processing Record 7 of Set 14 | saint anthony
# Processing Record 8 of Set 14 | vyazemskiy
# Processing Record 9 of Set 14 | jadu
# Processing Record 10 of Set 14 | north bend
# Processing Record 11 of Set 14 | harnosand
# Processing Record 12 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 13 of Set 14 | dunyapur
# Processing Record 14 of Set 14 | notse
# Processing Record 15 of Set 14 | slave lake
# Processing Record 16 of Set 14 | tres arroyos
# Processing Record 17 of Set 14 | port augusta
# Processing Record 18 of Set 14 | tecolutilla
# Processing Record 19 of Set 14 | vagur
# Processing Record 20 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 21 of Set 14 | fairbanks
# Processing Record 22 of Set 14 | south lake tahoe
# Processing Record 23 of Set 14 | yuyao
# Processing Record 24 of Set 14 | pitimbu
# Processing Record 25 of Set 14 | toowoomba
# Processing Record 26 of Set 14 | paamiut
# Processing Record 27 of Set 14 | coquimbo
# Processing Record 28 of Set 14 | pushkinskiye gory
# Processing Record 29 of Set 14 | iskateley
# Processing Record 30 of Set 14 | miri
# Processing Record 31 of Set 14 | strezhevoy
# Processing Record 32 of Set 14 | bilibino
# Processing Record 33 of Set 14 | porto santo
# Processing Record 34 of Set 14 | wrzesnia
# Processing Record 35 of Set 14 | lar gerd
# City not found. Skipping...
# Processing Record 36 of Set 14 | morondava
# Processing Record 37 of Set 14 | eureka
# Processing Record 38 of Set 14 | brae
# Processing Record 39 of Set 14 | mpika
# Processing Record 40 of Set 14 | kloulklubed
# Processing Record 41 of Set 14 | misratah
# Processing Record 42 of Set 14 | guarapari
# Processing Record 43 of Set 14 | sydney mines
# Processing Record 44 of Set 14 | saint-marc-des-carrieres
# Processing Record 45 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 14 | aleksin
# Processing Record 47 of Set 14 | kapoeta
# Processing Record 48 of Set 14 | neuquen
# Processing Record 49 of Set 14 | loandjili
# Processing Record 50 of Set 14 | mayo
# Processing Record 1 of Set 15 | okato
# Processing Record 2 of Set 15 | maragogi
# Processing Record 3 of Set 15 | nome
# Processing Record 4 of Set 15 | novo aripuana
# Processing Record 5 of Set 15 | kieta
# Processing Record 6 of Set 15 | halifax
# Processing Record 7 of Set 15 | boatlaname
# City not found. Skipping...
# Processing Record 8 of Set 15 | trairi
# Processing Record 9 of Set 15 | cuenca
# Processing Record 10 of Set 15 | suda
# Processing Record 11 of Set 15 | ixtapa
# Processing Record 12 of Set 15 | pleshanovo
# Processing Record 13 of Set 15 | khorinsk
# Processing Record 14 of Set 15 | siva
# Processing Record 15 of Set 15 | ayan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 666

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Carnarvon -24.8667  113.6333     71.67        64          40
# 1     Cape Town -33.9258   18.4232     54.27        92          75
# 2       Rikitea -23.1203 -134.9692     74.05        79         100
# 3       Iqaluit  63.7506  -68.5145     26.33        92          20
# 4    Bredasdorp -34.5322   20.0403     45.72        87          97
# 5     Busselton -33.6500  115.3333     61.05        55           3
# 6  Punta Arenas -53.1500  -70.9167     37.51        87          40
# 7  Saint-Joseph -21.3667   55.6167     68.36        78           4
# 8     Petukhovo  55.0692   67.9019     43.61        59          61
# 9        Dikson  73.5069   80.5464     35.96        88         100
#
#    Wind Speed Country Current Description
# 0       16.11      AU    scattered clouds
# 1        2.30      ZA       broken clouds
# 2       16.71      PF          light rain
# 3       10.00      CA          few clouds
# 4        4.61      ZA     overcast clouds
# 5       16.46      AU           clear sky
# 6       11.50      CL    scattered clouds
# 7       12.66      RE           clear sky
# 8        6.76      RU       broken clouds
# 9       17.38      RU     overcast clouds

# %%
# Reorder columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Carnarvon      AU -24.8667  113.6333     71.67        64          40
# 1     Cape Town      ZA -33.9258   18.4232     54.27        92          75
# 2       Rikitea      PF -23.1203 -134.9692     74.05        79         100
# 3       Iqaluit      CA  63.7506  -68.5145     26.33        92          20
# 4    Bredasdorp      ZA -34.5322   20.0403     45.72        87          97
# 5     Busselton      AU -33.6500  115.3333     61.05        55           3
# 6  Punta Arenas      CL -53.1500  -70.9167     37.51        87          40
# 7  Saint-Joseph      RE -21.3667   55.6167     68.36        78           4
# 8     Petukhovo      RU  55.0692   67.9019     43.61        59          61
# 9        Dikson      RU  73.5069   80.5464     35.96        88         100
#
#    Wind Speed Current Description
# 0       16.11    scattered clouds
# 1        2.30       broken clouds
# 2       16.71          light rain
# 3       10.00          few clouds
# 4        4.61     overcast clouds
# 5       16.46           clear sky
# 6       11.50    scattered clouds
# 7       12.66           clear sky
# 8        6.76       broken clouds
# 9       17.38     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City ID")
